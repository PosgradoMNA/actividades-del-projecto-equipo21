# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo21/blob/main/Proyecto_final_Avance_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ciencia y analítica de datos
#
# ![image.png](data:image/png;base64,...)
#
# **Maestria en Inteligencia Artificial Aplicada**

# %% [markdown]
# Proyecto final - Avance 2
#
#                                                      AXXXXXXXX
#                                                      A01081266
#
# Objetivos
#
#
# > Identificar y aprender una metodología para usar durante realización del proyecto final.
#
#
#
# #Tetodología CRISP DM
#
# la Metodología CRIP-DM (del acrónimo ingles: CRoss Industry Standard Process for Data Mining), es un modelo de proceso que sirve como base para los procesos de ciencia de datos, consite en 6 pasos
#
#
# **1.Entendimiento del negocio**
# >Se enfoca en entender los objetivos y requerimientos del proyecto, determinando el criterio de éxito, recursos disponibles, requerimientos, riesgos, objetivos y la planeación.
#
# **2.   Entendimiento de los datos**
# >En esta etapa se obtienen los datos necesarios, se describen, exploran y se verifica la calidad de los datos
#
# **3. Preparacion de los datos**
# >Seleccion de los datos serán usados para cumplir los objetivos. Se realiza limpieza de datos, se integran y se da el formato adecuado.
#
# **4. Modelado**
# > Se seleccionan las técnicas de modelado, determinando que algoritmos se usaran. Construcción del modelo, pudiendo elaborar una evaluación entre diferentes modelos.
#
# **5. Evaluacion**
# >Se evaluan los resultados en funcion del cumplimiento del criterio de éxito, se revisa el proceso y se determinan los siguientes pasos
#
# **6. Despliegue**
# >Se planea el despliegue: desarrollando y documentando el plan de accion, incluyendo monitoreo y mantenimiento. Reporte final y revision de proyecto.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Referencias**
#
# * https://thinkinsights.net/data-literacy/crisp-dm/
#
# * https://www.datascience-pm.com/crisp-dm-2/
# * IBM-ASUM
# * https://www.datascience-pm.com/crisp-dm-2/
# * https://miro.com/es/
